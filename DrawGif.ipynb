# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.animation as animation

# %%
data = np.load('data.npy')
data
# Out:
# array([[[   0.        ,   13.179     ],
#         [   0.        , 1452.20599439],
#         [   0.        , 3027.72032024],
#         [   0.        , 3924.79135599],
#         [   0.        , 4675.58591053]],
#
#        [[   0.        ,   16.779     ],
#         [   0.        , 1246.5880746 ],
#         [   0.        , 1843.8018667 ],
#         [   0.        , 2596.33488291],
#         [   0.        , 3307.65350793]],
#
#        [[  13.4546    ,    0.        ],
#         [ 745.13497475,    0.        ],
#         [1125.92657533,    0.        ],
#         [2501.20952225,    0.        ],
#         [3440.31096353,    0.        ]],
#
#        ...,
#
#        [[   0.        ,   13.579     ],
#         [   0.        , 1243.02108057],
#         [   0.        , 2186.67609117],
#         [   0.        , 2912.16084477],
#         [   0.        , 3466.84060216]],
#
#        [[  15.6546    ,    0.        ],
#         [ 555.66714368,    0.        ],
#         [1723.04163548,    0.        ],
#         [3394.81289563,    0.        ],
#         [4179.41167535,    0.        ]],
#
#        [[  14.0546    ,    0.        ],
#         [ 732.45726525,    0.        ],
#         [1338.91185169,    0.        ],
#         [2535.87341586,    0.        ],
#         [2988.90018538,    0.        ]]])

# %%
def update_lines(num, dataLines, lines):
    for line, data in zip(lines, dataLines):
        # NOTE: there is no .set_data() for 3 dim data...
        line.set_data(data[0:2, :num])
        line.set_3d_properties(data[2, :num])
    return lines

# %%
def transitTime():
    newData = []
    for d in data:
        s = []
        for i in range(len(d)):
            tmp = [d[i, 0], d[i, 1], i]
            s.append(tmp)
        newData.append(s)

    return np.array(newData)

# %%
newData = transitTime()
newData
# Out:
# array([[[0.00000000e+00, 1.31790000e+01, 0.00000000e+00],
#         [0.00000000e+00, 1.45220599e+03, 1.00000000e+00],
#         [0.00000000e+00, 3.02772032e+03, 2.00000000e+00],
#         [0.00000000e+00, 3.92479136e+03, 3.00000000e+00],
#         [0.00000000e+00, 4.67558591e+03, 4.00000000e+00]],
#
#        [[0.00000000e+00, 1.67790000e+01, 0.00000000e+00],
#         [0.00000000e+00, 1.24658807e+03, 1.00000000e+00],
#         [0.00000000e+00, 1.84380187e+03, 2.00000000e+00],
#         [0.00000000e+00, 2.59633488e+03, 3.00000000e+00],
#         [0.00000000e+00, 3.30765351e+03, 4.00000000e+00]],
#
#        [[1.34546000e+01, 0.00000000e+00, 0.00000000e+00],
#         [7.45134975e+02, 0.00000000e+00, 1.00000000e+00],
#         [1.12592658e+03, 0.00000000e+00, 2.00000000e+00],
#         [2.50120952e+03, 0.00000000e+00, 3.00000000e+00],
#         [3.44031096e+03, 0.00000000e+00, 4.00000000e+00]],
#
#        ...,
#
#        [[0.00000000e+00, 1.35790000e+01, 0.00000000e+00],
#         [0.00000000e+00, 1.24302108e+03, 1.00000000e+00],
#         [0.00000000e+00, 2.18667609e+03, 2.00000000e+00],
#         [0.00000000e+00, 2.91216084e+03, 3.00000000e+00],
#         [0.00000000e+00, 3.46684060e+03, 4.00000000e+00]],
#
#        [[1.56546000e+01, 0.00000000e+00, 0.00000000e+00],
#         [5.55667144e+02, 0.00000000e+00, 1.00000000e+00],
#         [1.72304164e+03, 0.00000000e+00, 2.00000000e+00],
#         [3.39481290e+03, 0.00000000e+00, 3.00000000e+00],
#         [4.17941168e+03, 0.00000000e+00, 4.00000000e+00]],
#
#        [[1.40546000e+01, 0.00000000e+00, 0.00000000e+00],
#         [7.32457265e+02, 0.00000000e+00, 1.00000000e+00],
#         [1.33891185e+03, 0.00000000e+00, 2.00000000e+00],
#         [2.53587342e+03, 0.00000000e+00, 3.00000000e+00],
#         [2.98890019e+03, 0.00000000e+00, 4.00000000e+00]]])

# %%
def changeShape():
    dataChange = []
    for d in newData:
        x = [i[0] for i in d]
        y = [i[2] for i in d]
        z = [i[1] for i in d]
        dataChange.append([x,y,z])

    return np.array(dataChange)

# %%
dataChange = changeShape()
dataChange
# Out:
# array([[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00],
#         [0.00000000e+00, 1.00000000e+00, 2.00000000e+00, 3.00000000e+00,
#          4.00000000e+00],
#         [1.31790000e+01, 1.45220599e+03, 3.02772032e+03, 3.92479136e+03,
#          4.67558591e+03]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00],
#         [0.00000000e+00, 1.00000000e+00, 2.00000000e+00, 3.00000000e+00,
#          4.00000000e+00],
#         [1.67790000e+01, 1.24658807e+03, 1.84380187e+03, 2.59633488e+03,
#          3.30765351e+03]],
#
#        [[1.34546000e+01, 7.45134975e+02, 1.12592658e+03, 2.50120952e+03,
#          3.44031096e+03],
#         [0.00000000e+00, 1.00000000e+00, 2.00000000e+00, 3.00000000e+00,
#          4.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00]],
#
#        ...,
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00],
#         [0.00000000e+00, 1.00000000e+00, 2.00000000e+00, 3.00000000e+00,
#          4.00000000e+00],
#         [1.35790000e+01, 1.24302108e+03, 2.18667609e+03, 2.91216084e+03,
#          3.46684060e+03]],
#
#        [[1.56546000e+01, 5.55667144e+02, 1.72304164e+03, 3.39481290e+03,
#          4.17941168e+03],
#         [0.00000000e+00, 1.00000000e+00, 2.00000000e+00, 3.00000000e+00,
#          4.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00]],
#
#        [[1.40546000e+01, 7.32457265e+02, 1.33891185e+03, 2.53587342e+03,
#          2.98890019e+03],
#         [0.00000000e+00, 1.00000000e+00, 2.00000000e+00, 3.00000000e+00,
#          4.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#          0.00000000e+00]]])

# %%
fig = plt.figure(figsize=(12,11))
ax = p3.Axes3D(fig)

# %%
lines = [ax.plot(dat[0, 0:1], dat[1, 0:1], dat[2, 0:1])[0] for dat in dataChange]

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
ax.set_xlim3d([0.0, 6000])
ax.set_xlabel('金融能力')

ax.set_ylim3d([0.0, 4])
ax.set_ylabel('时间')

ax.set_zlim3d([0.0, 7000])
ax.set_zlabel('计算机能力')

ax.view_init(10, 50)
# ax.set_title('Simulation on Student')

# %%
line_ani = animation.FuncAnimation(fig, update_lines, 5, fargs=(dataChange, lines),
                                   interval=400, blit=False)
line_ani.save('simu.gif')
# plt.show()
print('finished')
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
# finished
