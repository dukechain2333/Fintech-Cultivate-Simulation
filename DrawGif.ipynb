# %%
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import mpl_toolkits.mplot3d.axes3d as p3
import matplotlib.animation as animation

# %%
# data = np.load('data.npy')
data = np.load('data2.npy')
data
# Out:
# array([[[0.00000000e+00, 1.55790000e+01],
#         [0.00000000e+00, 9.36253221e+02],
#         [0.00000000e+00, 2.20781132e+03],
#         ...,
#         [0.00000000e+00, 5.07829628e+04],
#         [0.00000000e+00, 5.18558454e+04],
#         [0.00000000e+00, 5.31911270e+04]],
#
#        [[0.00000000e+00, 1.45790000e+01],
#         [0.00000000e+00, 1.54211591e+03],
#         [0.00000000e+00, 2.19755808e+03],
#         ...,
#         [0.00000000e+00, 4.86536864e+04],
#         [0.00000000e+00, 5.01230424e+04],
#         [0.00000000e+00, 5.07119290e+04]],
#
#        [[1.40546000e+01, 0.00000000e+00],
#         [8.90612958e+02, 0.00000000e+00],
#         [1.68578824e+03, 0.00000000e+00],
#         ...,
#         [4.91060931e+04, 0.00000000e+00],
#         [5.03257347e+04, 0.00000000e+00],
#         [5.06466687e+04, 0.00000000e+00]],
#
#        ...,
#
#        [[1.36546000e+01, 0.00000000e+00],
#         [1.79941986e+03, 0.00000000e+00],
#         [3.05500523e+03, 0.00000000e+00],
#         ...,
#         [4.87971384e+04, 0.00000000e+00],
#         [4.95939213e+04, 0.00000000e+00],
#         [5.07781183e+04, 0.00000000e+00]],
#
#        [[1.70546000e+01, 0.00000000e+00],
#         [7.34603356e+02, 0.00000000e+00],
#         [1.79631294e+03, 0.00000000e+00],
#         ...,
#         [4.83135998e+04, 0.00000000e+00],
#         [4.93855625e+04, 0.00000000e+00],
#         [5.06777323e+04, 0.00000000e+00]],
#
#        [[0.00000000e+00, 1.63790000e+01],
#         [0.00000000e+00, 7.88729174e+02],
#         [0.00000000e+00, 1.67666051e+03],
#         ...,
#         [0.00000000e+00, 5.15871582e+04],
#         [0.00000000e+00, 5.19781455e+04],
#         [0.00000000e+00, 5.27048371e+04]]])

# %%
def update_lines(num, dataLines, lines):
    for line, data in zip(lines, dataLines):
        # NOTE: there is no .set_data() for 3 dim data...
        line.set_data(data[0:2, :num])
        line.set_3d_properties(data[2, :num])
    return lines

# %%
def transitTime():
    newData = []
    for d in data:
        s = []
        for i in range(len(d)):
            tmp = [d[i, 0], d[i, 1], i]
            s.append(tmp)
        newData.append(s)

    return np.array(newData)

# %%
newData = transitTime()
newData
# Out:
# array([[[0.00000000e+00, 1.55790000e+01, 0.00000000e+00],
#         [0.00000000e+00, 9.36253221e+02, 1.00000000e+00],
#         [0.00000000e+00, 2.20781132e+03, 2.00000000e+00],
#         ...,
#         [0.00000000e+00, 5.07829628e+04, 4.80000000e+01],
#         [0.00000000e+00, 5.18558454e+04, 4.90000000e+01],
#         [0.00000000e+00, 5.31911270e+04, 5.00000000e+01]],
#
#        [[0.00000000e+00, 1.45790000e+01, 0.00000000e+00],
#         [0.00000000e+00, 1.54211591e+03, 1.00000000e+00],
#         [0.00000000e+00, 2.19755808e+03, 2.00000000e+00],
#         ...,
#         [0.00000000e+00, 4.86536864e+04, 4.80000000e+01],
#         [0.00000000e+00, 5.01230424e+04, 4.90000000e+01],
#         [0.00000000e+00, 5.07119290e+04, 5.00000000e+01]],
#
#        [[1.40546000e+01, 0.00000000e+00, 0.00000000e+00],
#         [8.90612958e+02, 0.00000000e+00, 1.00000000e+00],
#         [1.68578824e+03, 0.00000000e+00, 2.00000000e+00],
#         ...,
#         [4.91060931e+04, 0.00000000e+00, 4.80000000e+01],
#         [5.03257347e+04, 0.00000000e+00, 4.90000000e+01],
#         [5.06466687e+04, 0.00000000e+00, 5.00000000e+01]],
#
#        ...,
#
#        [[1.36546000e+01, 0.00000000e+00, 0.00000000e+00],
#         [1.79941986e+03, 0.00000000e+00, 1.00000000e+00],
#         [3.05500523e+03, 0.00000000e+00, 2.00000000e+00],
#         ...,
#         [4.87971384e+04, 0.00000000e+00, 4.80000000e+01],
#         [4.95939213e+04, 0.00000000e+00, 4.90000000e+01],
#         [5.07781183e+04, 0.00000000e+00, 5.00000000e+01]],
#
#        [[1.70546000e+01, 0.00000000e+00, 0.00000000e+00],
#         [7.34603356e+02, 0.00000000e+00, 1.00000000e+00],
#         [1.79631294e+03, 0.00000000e+00, 2.00000000e+00],
#         ...,
#         [4.83135998e+04, 0.00000000e+00, 4.80000000e+01],
#         [4.93855625e+04, 0.00000000e+00, 4.90000000e+01],
#         [5.06777323e+04, 0.00000000e+00, 5.00000000e+01]],
#
#        [[0.00000000e+00, 1.63790000e+01, 0.00000000e+00],
#         [0.00000000e+00, 7.88729174e+02, 1.00000000e+00],
#         [0.00000000e+00, 1.67666051e+03, 2.00000000e+00],
#         ...,
#         [0.00000000e+00, 5.15871582e+04, 4.80000000e+01],
#         [0.00000000e+00, 5.19781455e+04, 4.90000000e+01],
#         [0.00000000e+00, 5.27048371e+04, 5.00000000e+01]]])

# %%
def changeShape():
    dataChange = []
    for d in newData:
        x = [i[0] for i in d]
        y = [i[2] for i in d]
        z = [i[1] for i in d]
        dataChange.append([x,y,z])

    return np.array(dataChange)

# %%
dataChange = changeShape()
dataChange
# Out:
# array([[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 1.00000000e+00, 2.00000000e+00, ...,
#          4.80000000e+01, 4.90000000e+01, 5.00000000e+01],
#         [1.55790000e+01, 9.36253221e+02, 2.20781132e+03, ...,
#          5.07829628e+04, 5.18558454e+04, 5.31911270e+04]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 1.00000000e+00, 2.00000000e+00, ...,
#          4.80000000e+01, 4.90000000e+01, 5.00000000e+01],
#         [1.45790000e+01, 1.54211591e+03, 2.19755808e+03, ...,
#          4.86536864e+04, 5.01230424e+04, 5.07119290e+04]],
#
#        [[1.40546000e+01, 8.90612958e+02, 1.68578824e+03, ...,
#          4.91060931e+04, 5.03257347e+04, 5.06466687e+04],
#         [0.00000000e+00, 1.00000000e+00, 2.00000000e+00, ...,
#          4.80000000e+01, 4.90000000e+01, 5.00000000e+01],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        ...,
#
#        [[1.36546000e+01, 1.79941986e+03, 3.05500523e+03, ...,
#          4.87971384e+04, 4.95939213e+04, 5.07781183e+04],
#         [0.00000000e+00, 1.00000000e+00, 2.00000000e+00, ...,
#          4.80000000e+01, 4.90000000e+01, 5.00000000e+01],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[1.70546000e+01, 7.34603356e+02, 1.79631294e+03, ...,
#          4.83135998e+04, 4.93855625e+04, 5.06777323e+04],
#         [0.00000000e+00, 1.00000000e+00, 2.00000000e+00, ...,
#          4.80000000e+01, 4.90000000e+01, 5.00000000e+01],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 1.00000000e+00, 2.00000000e+00, ...,
#          4.80000000e+01, 4.90000000e+01, 5.00000000e+01],
#         [1.63790000e+01, 7.88729174e+02, 1.67666051e+03, ...,
#          5.15871582e+04, 5.19781455e+04, 5.27048371e+04]]])

# %%
fig = plt.figure(figsize=(12,11))
ax = p3.Axes3D(fig)

# %%
lines = [ax.plot(dat[0, 0:1], dat[1, 0:1], dat[2, 0:1])[0] for dat in dataChange]

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']
plt.rcParams['axes.unicode_minus'] = False
# ax.set_xlim3d([0.0, 6000])
ax.set_xlim3d([0.0, 50000])
ax.set_xlabel('金融能力')

# ax.set_ylim3d([0.0, 4])
ax.set_ylim3d([0.0, 40])
ax.set_ylabel('时间')

# ax.set_zlim3d([0.0, 7000])
ax.set_zlim3d([0.0, 70000])
ax.set_zlabel('计算机能力')

# ax.view_init(10, 50)
ax.view_init(10, 30)
# ax.set_title('Simulation on Student')

# %%
# line_ani = animation.FuncAnimation(fig, update_lines, 5, fargs=(dataChange, lines),
#                                    interval=500, blit=False)
line_ani = animation.FuncAnimation(fig, update_lines, 41, fargs=(dataChange, lines),
                                   interval=110, blit=False)
line_ani.save('SimulationDynamic.gif')
# plt.show()
print('finished')
# Out:
# MovieWriter ffmpeg unavailable; using Pillow instead.
# finished
