# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.mlab as mlab
from scipy.stats import gamma

# %%
data = np.load('data.npy')
data
# Out:
# array([[[   0.        ,   13.179     ],
#         [   0.        , 1452.20599439],
#         [   0.        , 3027.72032024],
#         [   0.        , 3924.79135599],
#         [   0.        , 4675.58591053]],
#
#        [[   0.        ,   16.779     ],
#         [   0.        , 1246.5880746 ],
#         [   0.        , 1843.8018667 ],
#         [   0.        , 2596.33488291],
#         [   0.        , 3307.65350793]],
#
#        [[  13.4546    ,    0.        ],
#         [ 745.13497475,    0.        ],
#         [1125.92657533,    0.        ],
#         [2501.20952225,    0.        ],
#         [3440.31096353,    0.        ]],
#
#        ...,
#
#        [[   0.        ,   13.579     ],
#         [   0.        , 1243.02108057],
#         [   0.        , 2186.67609117],
#         [   0.        , 2912.16084477],
#         [   0.        , 3466.84060216]],
#
#        [[  15.6546    ,    0.        ],
#         [ 555.66714368,    0.        ],
#         [1723.04163548,    0.        ],
# ...

# %%
lastPointGroup = []
# print(data[0][-1])
for d in data:
    lastPointGroup.append(d[-1])
lastPointGroup=np.array(lastPointGroup)
lastPointGroup
# Out:
# array([[   0.        , 4675.58591053],
#        [   0.        , 3307.65350793],
#        [3440.31096353,    0.        ],
#        ...,
#        [   0.        , 3466.84060216],
#        [4179.41167535,    0.        ],
#        [2988.90018538,    0.        ]])

# %%
lastFinance = []
lastCS = []
for i in lastPointGroup:
    if i[0]==0 or i[1]==0:
        pass
    else:
        lastFinance.append(i[0])
        lastCS.append(i[1])
print(lastFinance)
print('-----------------------------------')
print(lastCS)
# Out:
# [3682.3901531138613, 3395.797680180721, 4684.99644118866, 4007.182697668856, 3996.02174372066, 4823.857624784145, 3789.9117316073325, 4006.810063661474, 4226.737693900611, 3263.59069986994, 3830.1003297655634, 3198.907837106198, 4863.5666496423355, 3053.35596621045, 3484.3549177658747, 4623.961999931097, 3606.4446676409425, 4432.876417869899, 5731.598929711985, 4237.968909231013, 3732.079008908008, 4478.757897359712, 2745.4454097915136, 4413.689579591473, 4470.660780642228, 3830.767464283342, 5148.701528889551, 3725.016527252254, 3661.1843190659088, 4100.761177941302, 5600.712266192929, 4185.919935904154, 3152.2679736407176, 5086.916502894105, 3245.9694256054004, 4051.7717952504404, 4720.708633143955, 4389.398279358252, 4807.961200191047, 3401.8338401822, 3622.7681562223916, 3299.7676282831085, 4148.571899843617, 3035.2938210243638, 3813.9729770896297, 4521.320912722889, 3956.6719793560137, 4111.222941168483, 4349.576316708698, 4297.663119920247, 4203.687789533171, 4723.543430910753,
# ...

# %%
financeThreshold = np.percentile(lastFinance,25)
financeThreshold
# Out:
# 3561.0393570892406

# %%
CSThreshold = np.percentile(lastCS,25)
CSThreshold
# Out:
# 5341.559035633861

# %%
plt.figure(figsize=(20, 20))
sns.set_style('darkgrid')
ax = sns.displot(lastFinance,color='blue',kde=True)
plt.axvline(3561.0393570892406,ls='--',color='red')
plt.annotate("Pass Line",xy=(3561.0393570892406,35),xytext=(2500,40),arrowprops = dict(facecolor = "r", headlength = 5, headwidth = 15, width = 5))
plt.title('Distribution map of Financial Ability')
plt.ylabel('Number of Students')
ax.set_xlabels('Ability of Finance')
plt.savefig('DistributionFinance.png')

# %%
plt.figure(figsize=(20, 20))
sns.set_style('darkgrid')
ax = sns.displot(lastCS,color='blue',kde=True)
plt.axvline(5341.559035633861,ls='--',color='red')
plt.annotate("Pass Line",xy=(5341.559035633861,35),xytext=(4000,40),arrowprops = dict(facecolor = "r", headlength = 5, headwidth = 15, width = 5))
plt.title('Distribution map of CS ability')
plt.ylabel('Number of Students')
ax.set_xlabels('Ability of CS')
plt.savefig('DistributionCS.png')
